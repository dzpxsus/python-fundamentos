# %% [markdown]
# Pergunta dados ao utilizador..

# %%
nome = str(input("Qual é o teu nome? "))
idade = int(input("Qual é a tua idade? "))
peso = float(input("Qual é o teu peso em kg? "))
# Out:
# Qual é o teu nome? 545
# Qual é a tua idade? dsds
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-447/2307684596.py in <cell line: 0>()
#       1 nome = str(input("Qual é o teu nome? "))
# ----> 2 idade = int(input("Qual é a tua idade? "))
#       3 peso = float(input("Qual é o teu peso em kg? "))
#
# ValueError: invalid literal for int() with base 10: 'dsds'

# %% [markdown]
# Apresenta os dados ao Utilizador.

# %%
print(f"Olá {nome}")
print(f"Tens {idade} anos")
print(f"Pesas {peso} kg")
print("Programa terminado")
